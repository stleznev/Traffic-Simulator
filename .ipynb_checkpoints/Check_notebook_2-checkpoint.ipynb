# %%
#Import the stuff that is done by now

from IPython.display import display

import time
import importlib
import sys
try:
    importlib.reload(sys.modules['Simulation_loop_copy'])
    importlib.reload(sys.modules['dijkstra_copy'])
    importlib.reload(sys.modules['Initialize_agents'])
    importlib.reload(sys.modules['Initialize_graph'])
except KeyError:
    pass

import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib
import random as rd
import numpy as np

from copy import deepcopy

from Initialize_graph import create_weighted_random_graph, draw_graph
from Initialize_agents import Agent, create_list_of_agents

from dijkstra_copy import find_index_2_levels, calculate_subjective_weight_for_edge_time,\
calculate_subjective_weight_for_edge_time_overall, dijkstra_with_time_dependent_weights, get_path, get_discount

from Simulation_loop_copy import simulation_baseline
from Simulation_loop_copy import simulation_navigator
from Simulation_loop_copy import simulation_PTA
from Simulation_loop_copy import dynamic_system

from testing import check_paths_and_travel_times
from testing import check_FIFO_property_baseline
from testing import check_expectations
from testing import check_reality

# %%
# Initialize graph
G = create_weighted_random_graph(n_nodes = 5, 
                                 n_edges = 15, 
                                 weights_from = 10, 
                                 weights_to = 30, 
                                 time_slot_size = 0.01)

# %%
# Draw graph
draw_graph(G)

# %%
# Initialize agents
agents = create_list_of_agents(num_agents = 700, 
                               graph = G, 
                               time_stamp = 0.01,
                               navi_user_prob = 1,
                               PTA_user_prob = 1)

# %%
# Initialize simulation
simulation = simulation_baseline(G, agents, max_time = 24)

# %%
# Make simulation
simulation.restore_all_agents_finally()
simulation.simulation_optimized(max_iters = 100)

# %%
#Comparison of total travel times: Baseline through iterations
def compare_results_base(base):
    overall_base_list = []
    for iteration in range(len(base.common_sense)):
        overall_base = 0
        for i in range(len(base.common_sense[iteration])):
            for p in range(len(base.common_sense[iteration][i].paths)):
                overall_base += base.common_sense[iteration][i].real_edge_times[p][-1][-1] \
                - base.common_sense[iteration][i].real_edge_times[p][0][0]
        overall_base_list.append(round(overall_base, 2))
    return overall_base_list
#display(compare_results_base(simulation))
#display(simulation.paths_changed)

# %%
# Statistical info checks

# %%
# Find agent who came or left the edge at time = t
def find_agent_time(simulation, time, iteration):
    for a in simulation.common_sense[iteration]:
        for p in range(len(a.paths)):
            for edge_num in range(len(a.paths[p])-1):
                if a.real_edge_times[p][edge_num][0] == time:
                    print('ID', a.id_num, 'Path', p, 'Edge', (a.paths[p][edge_num], a.paths[p][edge_num+1]))
find_agent_time(simulation = simulation, time = 13.72, iteration = 9)

# %%
# Check to see id's of agents who arrive later than some time (currently 28)
for iteration in range(len(simulation.common_sense)):
    for a in simulation.common_sense[iteration]:
        for p in range(len(a.paths)):
            for edge in range(len(a.real_edge_times[p])):
                if a.real_edge_times[p][edge][1] >= 24:
                    print('Iteration', iteration, 'ID', a.id_num, 'Path', p)

# %%
# Function that outputs the id's of agents whose expectations about travel times for a trip
# are confronted by reality and the difference between them is more than value
# Works as intended only for iter == 0

def differences_between_expectations_and_reality(agents, value):
    for a in agents:
        for p in range(len(a.paths)):
            for edge in range(len(a.real_edge_times[p])):
                if a.real_edge_times[p][edge][1] - a.expected_edge_times[p][edge][1] >= value:
                    print('ID', a.id_num, 'Path', p)
                    
differences_between_expectations_and_reality(agents = simulation.common_sense[0], value = 1.4)

# %%
# Prints info about i'th agent in iteration's simulation

iteration = 0
i = 2
print('------AGENT %s------' %i)
print('Num of trips', simulation.common_sense[iteration][i].num_trips)
print('Paths', simulation.common_sense[iteration][i].paths)
print('Departures', simulation.common_sense[iteration][i].times_of_departures)
print('---------------------------------------------------------------------------------------------------')
print('Expected_edge_times', simulation.common_sense[iteration][i].expected_edge_times)
print('---------------------------------------------------------------------------------------------------')
print('real_edge_times', simulation.common_sense[iteration][i].real_edge_times)
print('---------------------------------------------------------------------------------------------------')
print('Speed by time', simulation.common_sense[iteration][i].speed_by_time)
print('---------------------------------------------------------------------------------------------------')
print('Edges passed', simulation.common_sense[iteration][i].edges_passed)
print('---------------------------------------------------------------------------------------------------')
print('Original departures', simulation.common_sense[iteration][i].original_times_of_departures)

# %%
# Outputs the id's of agents whose real_travel_times changed from previous to current iteration

counter_overall = [0]*(len(simulation.common_sense)-1)
counter_agents = [[0]*len(simulation.common_sense[0]) for i in range(len(simulation.common_sense)-1)]
for iteration in range(1,len(simulation.common_sense)):
    for a in simulation.common_sense[iteration]:
        for p in range(0,len(a.paths)):
            if a.real_edge_times[p][0][0] - a.real_edge_times[p][-1][1] != \
            simulation.common_sense[iteration-1][a.id_num].real_edge_times[p][0][0]\
            - simulation.common_sense[iteration-1][a.id_num].real_edge_times[p][-1][1]:
                #print('Iteration', iteration, 'ID', a.id_num, 'Path', p)
                counter_overall[iteration-1] += 1
                counter_agents[iteration-1][a.id_num] += 1

print('--------------------------------------------------------------------')
# Counter shows how many trips per iteration were influenced by the changes 
# in paths of others (or the agent himself).
print('Counter:', counter_overall)

counter_agents_out = [0]*len(counter_agents)
for i in range(len(counter_agents)):
    for id_num in range(len(counter_agents[i])):
        if counter_agents[i][id_num] != 0:
            counter_agents_out[i] += 1
# This counter shows how many agents per iteration experienced changes in times of trips
print('Counter for agents', counter_agents_out)

# %%
#Simulation navigator
for a in agents:
    a.navigator_user = np.random.choice((True, False), p = [0.5, 0.5])
    a.PTA_user = np.random.choice((True, False), p = [0.5, 0.5])

# %%
#Initialize simulation navigator
simulation2 = simulation_navigator(graph = G, agents = agents, max_time = simulation.max_time, \
                                   common_sense = deepcopy(simulation.common_sense))

# %%
#Make simulation
simulation2.restore_all_agents_finally()
simulation2.simulation_optimized(max_iters = 20)

# %%
#Simulation PTA
for a in agents:
    a.navigator_user = np.random.choice((True, False), p = [1.0, 0.0])
    a.PTA_user = np.random.choice((True, False), p = [1.0, 0.0])

# %%
#Initialize simulation
simulation3 = simulation_PTA(graph = G, agents = agents, max_time = simulation2.max_time, \
               historical_data = simulation2.statistics[0], \
               common_sense = deepcopy(simulation.common_sense), \
               cars_ahead = simulation2.cars_ahead)

# %%
#Make simulation
simulation3.restore_all_agents_finally()
simulation3.simulation_optimized(max_iters = 15)

# %%
#Statistical info checks for all 3 simulations

# %%
#Comparison of number of paths of agents by the source of their assignment (Baseline vs Navi vs PTA)
counter_navi = 0
counter_base = 0
counter_PTA = 0
absolute_base = 0
absolute_navi = 0
absolute_PTA = 0
changed_paths = 0
equal = 0
p_overall = 0

for i in range(len(simulation.statistics[0])):
    for p in range(len(simulation.statistics[0][i].paths)):
        p_overall += 1
        
        diff_base = \
        simulation.statistics[0][i].real_edge_times[p][-1][-1] \
        - simulation.statistics[0][i].real_edge_times[p][0][0]
        
        diff_navi = \
        simulation2.statistics[0][i].real_edge_times[p][-1][-1] \
        - simulation2.statistics[0][i].real_edge_times[p][0][0]
        
        diff_PTA = \
        simulation3.statistics[0][i].real_edge_times[p][-1][-1] \
        - simulation3.statistics[0][i].real_edge_times[p][0][0]

        min_val = min(diff_base, diff_navi, diff_PTA)
        if min_val == diff_base:
            counter_base += 1
        if min_val == diff_navi:
            counter_navi += 1
        if min_val == diff_PTA:
            counter_PTA += 1
        if min_val == diff_base and min_val != diff_navi and min_val != diff_PTA:
            absolute_base += 1
        if min_val == diff_navi and min_val != diff_base and min_val != diff_PTA:
            absolute_navi += 1
        if min_val == diff_PTA and min_val != diff_base and min_val != diff_navi:
            absolute_PTA += 1
        if min_val == diff_PTA and min_val == diff_base and min_val == diff_navi:
            equal += 1
            
print('Base', counter_base, 'Absolute', absolute_base)
print('Navi', counter_navi, 'Absolute', absolute_navi)
print('PTA', counter_PTA, 'Absolute', absolute_PTA)
print('Equal times', equal)
p_overall

# %%
del simulation, simulation2, simulation3

# %%
#Comparison of total travel times: Baseline vs Navigator vs PTA
def compare_results(base, navi, PTA):
    overall_base = 0
    overall_navi = 0
    overall_PTA = 0
    for i in range(len(base.statistics[0])):
        for p in range(len(base.statistics[0][i].paths)):
            overall_base += base.statistics[0][i].real_edge_times[p][-1][-1] \
            - base.statistics[0][i].real_edge_times[p][0][0]
            overall_navi += navi.statistics[0][i].real_edge_times[p][-1][-1] \
            - navi.statistics[0][i].real_edge_times[p][0][0]
            overall_PTA += PTA.statistics[0][i].real_edge_times[p][-1][-1]\
            - PTA.statistics[0][i].real_edge_times[p][0][0]
    #print('Base', round(overall_base, 2))
    #print('Navi', round(overall_navi, 2))
    #print('PTA', round(overall_PTA, 2))
    return round(overall_base, 2), round(overall_navi, 2), round(overall_PTA, 2)
#compare_results(simulation, simulation2, simulation3)

# %%
#Function that calculates the differences between expected and real edge times
#for every agent in a gien simulation
def get_diff_exp_real_trav_times(simulation, metric = 'full'):
    diff_list = dict((a, []) for a in range(len(simulation.statistics[0])))
    index = len(simulation.statistics) - 1
    for a in simulation.statistics[index]:
        for p in range(len(a.paths)):
            trav_time_real = a.real_edge_times[p][-1][-1] - a.real_edge_times[p][0][0]
            trav_time_exp = a.expected_edge_times[p][-1][-1] - a.expected_edge_times[p][0][0]
            diff_exp_reality = abs(trav_time_real - trav_time_exp)
            diff_list[a.id_num].append(diff_exp_reality)
    if metric == 'full':
        return diff_list
    elif metric == 'average':
        aver_agent = []
        for val in diff_list.values():
            aver_agent.append(sum(val)/len(val))
        return round(sum(aver_agent)/len(aver_agent), 4)
    elif metric == 'maximum':
        max_list = []
        for key, values in diff_list.items():
            max_list.append((key, max(values)))
        max_value = max(max_list, key = lambda x: x[1])
        return round(max_value[1], 3)

#print('Average difference base', get_diff_exp_real_trav_times(simulation, metric = 'average'))
#print('Average difference navi', get_diff_exp_real_trav_times(simulation2, metric = 'average'))
#print('Average difference PTA', get_diff_exp_real_trav_times(simulation3, metric = 'average'))

# %%
cong_hist_data2 = dict((e, dict((t, [0, []]) for t in range(0, int(simulation3.max_time / 0.01) + 1))) \
                    for e in simulation3.graph.edges())
for a in simulation3.statistics[0]:
    for p in range(len(a.paths)):
        for edge_num in range(len(a.paths[p])-1):
            start_time = a.real_edge_times[p][edge_num][0]
            finish_time = a.real_edge_times[p][edge_num][1]
            start_time = int(round(start_time / 0.01))
            finish_time = int(round(finish_time / 0.01))
            edge = a.edges_passed[p][edge_num]
            #time_range = finish_time - start_time
            #for time in range(0, int(round(time_range / 0.01)) + 1):
            for time in range(start_time, finish_time + 1):
                cong_hist_data2[edge][time][0] += 1
                if time == finish_time:
                    cong_hist_data2[edge][time][1].append('l')

# %%
for edge, time_list in cong_hist_data2.items():
    for t in range(len(time_list)):
        if cong_hist_data2[edge][t] != simulation3.trips_data[edge][t]:
            print('Time', t, 'Edge', edge)
            print('Real', cong_hist_data2[edge][t], 'Predicted', simulation3.trips_data[edge][t])

# %%
#Stuff for making simulations below

# %%
from multiprocessing import Pool
import pandas as pd

# %%
def make_results(num_iters_per_graph, num_proportions, init_agents = 400):
    data = dict()
    G = create_weighted_random_graph(n_nodes = 5, n_edges = 15, weights_from = 10, \
                                     weights_to = 30, time_slot_size = 0.01)
    data['graph'] = G
    data_loop = [[dict() for j in range(num_proportions)] for g in range(num_iters_per_graph)]
    for i in range(num_iters_per_graph):
        agents = create_list_of_agents(num_agents = init_agents * (i + 2), graph = G, time_stamp = 0.01, 
                                   navi_user_prob = 1.0, PTA_user_prob = 1.0)
        
        simulation = simulation_baseline(G, agents, max_time = 24)
        simulation.restore_all_agents_finally()
        simulation.simulation_optimized(max_iters = 30)
        check_expectations(simulation)
        check_reality(simulation)
        check_paths_and_travel_times(simulation)
        
        for k in range(num_proportions):
            proportion = (k + 1)*(1/num_proportions)
            for a in agents:
                a.navigator_user = np.random.choice((True, False), p = [proportion, 1 - proportion])
                a.PTA_user = np.random.choice((True, False), p = [proportion, 1 - proportion])

            simulation2 = simulation_navigator(graph = G, agents = agents, max_time = simulation.max_time, \
                                   common_sense = deepcopy(simulation.common_sense))
            simulation2.restore_all_agents_finally()
            simulation2.simulation_optimized(max_iters = 10)
            check_expectations(simulation2)
            check_reality(simulation2)
            check_paths_and_travel_times(simulation2)
            data_loop[i][k]['prop_navi_users'] = simulation2.proportion_users

            simulation3 = simulation_PTA(graph = G, agents = agents, max_time = simulation2.max_time + 4, \
                       historical_data = simulation2.statistics[0], \
                       common_sense = deepcopy(simulation.common_sense), \
                       cars_ahead = simulation2.cars_ahead)
            simulation3.restore_all_agents_finally()
            simulation3.simulation_optimized(max_iters = 10)
            check_expectations(simulation3)
            check_reality(simulation3)
            check_paths_and_travel_times(simulation3)
            data_loop[i][k]['prop_PTA_users'] = simulation3.proportion_users

            data_loop[i][k]['TTT_base'] = list(compare_results(simulation, simulation2, simulation3))[0]
            data_loop[i][k]['TTT_navi'] = list(compare_results(simulation, simulation2, simulation3))[1]
            data_loop[i][k]['TTT_PTA'] = list(compare_results(simulation, simulation2, simulation3))[2]
            data_loop[i][k]['diff_base'] = get_diff_exp_real_trav_times(simulation, metric = 'average')
            data_loop[i][k]['diff_navi'] = get_diff_exp_real_trav_times(simulation2, metric = 'average')
            data_loop[i][k]['diff_PTA'] = get_diff_exp_real_trav_times(simulation3, metric = 'average')
            
            cntr = 0
            for a in simulation.agents:
                    cntr += a.num_trips
            data_loop[i][k]['path_count'] = cntr
            
            data_loop[i][k]['convergence_base'] = compare_results_base(simulation)
            data_loop[i][k]['convergence_navi'] = compare_results_base(simulation2)
            data_loop[i][k]['convergence_PTA'] = compare_results_base(simulation3)
            print('-----------------------------------------------------------------------------------')
            print('------------------------------End of proportion iteration', k, '---------------------------')
        
        #Dynamic simulation with PTA
        dynamic_simulation = dynamic_system(graph = G, agents = agents, max_time = simulation2.max_time + 4,
                                    historical_data = simulation2.statistics[0],
                                    common_sense = deepcopy(simulation.common_sense),
                                    cars_ahead = simulation2.cars_ahead, all_three = True)
        dynamic_simulation.restore_all_agents_finally()
        dynamic_simulation.simulation_optimized(max_iters = 20)
        check_expectations(dynamic_simulation)
        check_reality(dynamic_simulation)
        check_paths_and_travel_times(dynamic_simulation)
        data_loop[i][0]['decomposition'] = user_decomposition(dynamic_simulation)
        data_loop[i][0]['TTT_DS'] = list(compare_results(dynamic_simulation, simulation2, simulation3))[0]
        data_loop[i][0]['diff_DS'] = get_diff_exp_real_trav_times(dynamic_simulation, metric = 'average')
        data_loop[i][0]['convergence_DS'] = compare_results_base(dynamic_simulation)
        del dynamic_simulation
        
        #Dynamic simulation without PTA
        dynamic_simulation2 = dynamic_system(graph = G, agents = agents, max_time = simulation2.max_time + 3,
                                    historical_data = simulation2.statistics[0],
                                    common_sense = deepcopy(simulation.common_sense),
                                    cars_ahead = simulation2.cars_ahead, all_three = False)
        dynamic_simulation2.restore_all_agents_finally()
        dynamic_simulation2.simulation_optimized(max_iters = 20)
        check_expectations(dynamic_simulation2)
        check_reality(dynamic_simulation2)
        check_paths_and_travel_times(dynamic_simulation2)
        data_loop[i][0]['decomposition2'] = user_decomposition(dynamic_simulation2)
        data_loop[i][0]['TTT_DS2'] = list(compare_results(dynamic_simulation2, simulation2, simulation3))[0]
        data_loop[i][0]['diff_DS2'] = get_diff_exp_real_trav_times(dynamic_simulation2, metric = 'average')
        data_loop[i][0]['convergence_DS2'] = compare_results_base(dynamic_simulation2)
        del simulation, simulation2, simulation3, dynamic_simulation2
        print('-----------------------------------------------------------------------------------')
        print('------------------------------End of load iteration', i, '---------------------------')
   
    print('-----------------------------------------------------------------------------------')
    print('------------------------------End of arch iteration---------------------------')
    data['loop'] = data_loop
    return data

# %%
st = time.time()
for f in range(1):
    data = make_results(4, 4, 400)
en = time.time()
print('Time elapsed in total', (en - st))
# Out:
# End of iteration 0 . Time elapsed: 4.98 sec
# End of iteration 1 . Time elapsed: 4.94 sec
# End of iteration 2 . Time elapsed: 5.02 sec
# End of iteration 3 . Time elapsed: 5.11 sec
# End of iteration 4 . Time elapsed: 5.89 sec
# End of iteration 5 . Time elapsed: 5.49 sec
# End of iteration 6 . Time elapsed: 5.6 sec
# Agents paths converged to user-equilibrium
# End of iteration 7 . Time elapsed: 5.74 sec
# End of simulation . Time elapsed: 42.94 sec
# End of iteration 0 . Time elapsed: 6.26 sec
# Agents paths converged to user-equilibrium
# End of iteration 1 . Time elapsed: 6.4 sec
# End of simulation . Time elapsed: 12.85 sec
# Preprocessing is done in 0.81 sec
# End of iteration 0 . Time elapsed: 35.55 sec
# End of iteration 1 . Time elapsed: 35.34 sec
# End of iteration 2 . Time elapsed: 34.73 sec
# End of iteration 3 . Time elapsed: 36.5 sec
# End of iteration 4 . Time elapsed: 37.27 sec
# End of iteration 5 . Time elapsed: 37.46 sec
# End of iteration 6 . Time elapsed: 37.5 sec
# End of iteration 7 . Time elapsed: 39.45 sec
# End of iteration 8 . Time elapsed: 39.05 sec
# End of iteration 9 . Time elapsed: 40.42 sec
# End of simulation . Time elapsed: 374.1 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 0 ---------------------------
# End of iteration 0 . Time elapsed: 7.25 sec
# Agents paths converged to user-equilibrium
# End of iteration 1 . Time elapsed: 6.57 sec
# End of simulation . Time elapsed: 14.01 sec
# Preprocessing is done in 0.19 sec
# End of iteration 0 . Time elapsed: 45.52 sec
# End of iteration 1 . Time elapsed: 49.51 sec
# End of iteration 2 . Time elapsed: 54.94 sec
# End of iteration 3 . Time elapsed: 58.87 sec
# End of iteration 4 . Time elapsed: 63.12 sec
# End of iteration 5 . Time elapsed: 66.37 sec
# End of iteration 6 . Time elapsed: 67.43 sec
# End of iteration 7 . Time elapsed: 71.28 sec
# End of iteration 8 . Time elapsed: 73.7 sec
# End of iteration 9 . Time elapsed: 75.38 sec
# End of simulation . Time elapsed: 626.32 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 1 ---------------------------
# End of iteration 0 . Time elapsed: 6.72 sec
# End of iteration 1 . Time elapsed: 6.95 sec
# Agents paths converged to user-equilibrium
# End of iteration 2 . Time elapsed: 6.84 sec
# End of simulation . Time elapsed: 21.47 sec
# Preprocessing is done in 0.23 sec
# End of iteration 0 . Time elapsed: 87.05 sec
# End of iteration 1 . Time elapsed: 92.83 sec
# End of iteration 2 . Time elapsed: 94.98 sec
# End of iteration 3 . Time elapsed: 102.81 sec
# End of iteration 4 . Time elapsed: 104.64 sec
# End of iteration 5 . Time elapsed: 110.8 sec
# End of iteration 6 . Time elapsed: 113.85 sec
# End of iteration 7 . Time elapsed: 119.05 sec
# End of iteration 8 . Time elapsed: 120.08 sec
# End of iteration 9 . Time elapsed: 127.37 sec
# End of simulation . Time elapsed: 1073.69 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 2 ---------------------------
# End of simulation . Time elapsed: 7.34 sec
# Preprocessing is done in 0.13 sec
# End of simulation . Time elapsed: 117.7 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 3 ---------------------------
# Preprocessing is done in 0.12 sec
# End of iteration 0 . Time elapsed: 126.15 sec
# End of iteration 1 . Time elapsed: 134.92 sec
# End of iteration 2 . Time elapsed: 132.26 sec
# End of iteration 3 . Time elapsed: 131.15 sec
# End of iteration 4 . Time elapsed: 128.25 sec
# End of iteration 5 . Time elapsed: 129.49 sec
# End of iteration 6 . Time elapsed: 117.91 sec
# End of iteration 7 . Time elapsed: 125.91 sec
# End of iteration 8 . Time elapsed: 126.99 sec
# End of iteration 9 . Time elapsed: 113.92 sec
# End of iteration 10 . Time elapsed: 127.25 sec
# End of iteration 11 . Time elapsed: 126.52 sec
# End of iteration 12 . Time elapsed: 128.54 sec
# End of iteration 13 . Time elapsed: 124.78 sec
# End of iteration 14 . Time elapsed: 129.29 sec
# End of iteration 15 . Time elapsed: 125.22 sec
# End of iteration 16 . Time elapsed: 129.19 sec
# End of iteration 17 . Time elapsed: 120.06 sec
# End of iteration 18 . Time elapsed: 128.04 sec
# End of iteration 19 . Time elapsed: 118.55 sec
# End of simulation . Time elapsed: 2524.5 sec
# Preprocessing is done in 0.14 sec
# End of iteration 0 . Time elapsed: 7.66 sec
# End of iteration 1 . Time elapsed: 7.66 sec
# End of iteration 2 . Time elapsed: 9.07 sec
# End of iteration 3 . Time elapsed: 8.35 sec
# End of iteration 4 . Time elapsed: 8.69 sec
# End of iteration 5 . Time elapsed: 8.98 sec
# End of iteration 6 . Time elapsed: 8.98 sec
# End of iteration 7 . Time elapsed: 10.57 sec
# End of iteration 8 . Time elapsed: 9.83 sec
# End of iteration 9 . Time elapsed: 9.82 sec
# End of iteration 10 . Time elapsed: 10.38 sec
# End of iteration 11 . Time elapsed: 11.57 sec
# End of iteration 12 . Time elapsed: 10.61 sec
# End of iteration 13 . Time elapsed: 11.18 sec
# End of iteration 14 . Time elapsed: 11.74 sec
# End of iteration 15 . Time elapsed: 11.92 sec
# End of iteration 16 . Time elapsed: 13.08 sec
# End of iteration 17 . Time elapsed: 12.49 sec
# End of iteration 18 . Time elapsed: 12.79 sec
# End of iteration 19 . Time elapsed: 13.44 sec
# End of simulation . Time elapsed: 208.96 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of load iteration 0 ---------------------------
# End of iteration 0 . Time elapsed: 7.32 sec
# End of iteration 1 . Time elapsed: 8.0 sec
# End of iteration 2 . Time elapsed: 8.43 sec
# End of iteration 3 . Time elapsed: 8.25 sec
# End of iteration 4 . Time elapsed: 8.39 sec
# End of iteration 5 . Time elapsed: 8.67 sec
# End of iteration 6 . Time elapsed: 9.44 sec
# End of iteration 7 . Time elapsed: 9.45 sec
# End of iteration 8 . Time elapsed: 9.46 sec
# Agents paths converged to user-equilibrium
# End of iteration 9 . Time elapsed: 9.8 sec
# End of simulation . Time elapsed: 87.5 sec
# End of iteration 0 . Time elapsed: 10.78 sec
# End of iteration 1 . Time elapsed: 11.59 sec
# End of iteration 2 . Time elapsed: 11.13 sec
# End of iteration 3 . Time elapsed: 11.34 sec
# End of iteration 4 . Time elapsed: 11.53 sec
# End of iteration 5 . Time elapsed: 11.92 sec
# Agents paths converged to user-equilibrium
# End of iteration 6 . Time elapsed: 12.18 sec
# End of simulation . Time elapsed: 81.58 sec
# Preprocessing is done in 1.66 sec
# End of iteration 0 . Time elapsed: 53.78 sec
# End of iteration 1 . Time elapsed: 55.69 sec
# End of iteration 2 . Time elapsed: 55.37 sec
# End of iteration 3 . Time elapsed: 57.03 sec
# End of iteration 4 . Time elapsed: 57.96 sec
# End of iteration 5 . Time elapsed: 59.35 sec
# End of iteration 6 . Time elapsed: 60.51 sec
# End of iteration 7 . Time elapsed: 61.92 sec
# End of iteration 8 . Time elapsed: 63.45 sec
# End of iteration 9 . Time elapsed: 64.0 sec
# End of simulation . Time elapsed: 590.76 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 0 ---------------------------
# End of iteration 0 . Time elapsed: 10.94 sec
# End of iteration 1 . Time elapsed: 11.24 sec
# Agents paths converged to user-equilibrium
# End of iteration 2 . Time elapsed: 12.65 sec
# End of simulation . Time elapsed: 35.13 sec
# Preprocessing is done in 0.42 sec
# End of iteration 0 . Time elapsed: 95.1 sec
# End of iteration 1 . Time elapsed: 93.08 sec
# End of iteration 2 . Time elapsed: 85.18 sec
# End of iteration 3 . Time elapsed: 77.58 sec
# End of iteration 4 . Time elapsed: 70.91 sec
# End of iteration 5 . Time elapsed: 70.98 sec
# End of iteration 6 . Time elapsed: 71.03 sec
# End of iteration 7 . Time elapsed: 72.36 sec
# End of iteration 8 . Time elapsed: 76.73 sec
# End of iteration 9 . Time elapsed: 79.1 sec
# End of simulation . Time elapsed: 792.48 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 1 ---------------------------
# End of iteration 0 . Time elapsed: 11.74 sec
# End of iteration 1 . Time elapsed: 12.65 sec
# End of iteration 2 . Time elapsed: 11.87 sec
# Agents paths converged to user-equilibrium
# End of iteration 3 . Time elapsed: 11.81 sec
# End of simulation . Time elapsed: 48.38 sec
# Preprocessing is done in 1.41 sec
# End of iteration 0 . Time elapsed: 105.9 sec
# End of iteration 1 . Time elapsed: 133.09 sec
# End of iteration 2 . Time elapsed: 155.07 sec
# End of iteration 3 . Time elapsed: 171.98 sec
# End of iteration 4 . Time elapsed: 184.97 sec
# End of iteration 5 . Time elapsed: 195.98 sec
# End of iteration 6 . Time elapsed: 207.22 sec
# End of iteration 7 . Time elapsed: 218.88 sec
# End of iteration 8 . Time elapsed: 228.36 sec
# End of iteration 9 . Time elapsed: 238.08 sec
# End of simulation . Time elapsed: 1840.94 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 2 ---------------------------
# End of simulation . Time elapsed: 13.37 sec
# Preprocessing is done in 0.22 sec
# End of simulation . Time elapsed: 188.85 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 3 ---------------------------
# Preprocessing is done in 0.21 sec
# End of iteration 0 . Time elapsed: 221.32 sec
# End of iteration 1 . Time elapsed: 214.83 sec
# End of iteration 2 . Time elapsed: 206.55 sec
# End of iteration 3 . Time elapsed: 201.16 sec
# End of iteration 4 . Time elapsed: 193.0 sec
# End of iteration 5 . Time elapsed: 200.4 sec
# End of iteration 6 . Time elapsed: 202.33 sec
# End of iteration 7 . Time elapsed: 188.87 sec
# End of iteration 8 . Time elapsed: 196.83 sec
# End of iteration 9 . Time elapsed: 199.91 sec
# End of iteration 10 . Time elapsed: 197.53 sec
# End of iteration 11 . Time elapsed: 196.63 sec
# End of iteration 12 . Time elapsed: 200.6 sec
# End of iteration 13 . Time elapsed: 196.55 sec
# End of iteration 14 . Time elapsed: 198.57 sec
# End of iteration 15 . Time elapsed: 197.01 sec
# End of iteration 16 . Time elapsed: 199.15 sec
# End of iteration 17 . Time elapsed: 191.79 sec
# End of iteration 18 . Time elapsed: 201.08 sec
# End of iteration 19 . Time elapsed: 202.85 sec
# End of simulation . Time elapsed: 4007.18 sec
# Preprocessing is done in 0.2 sec
# End of iteration 0 . Time elapsed: 13.26 sec
# End of iteration 1 . Time elapsed: 14.65 sec
# End of iteration 2 . Time elapsed: 14.05 sec
# End of iteration 3 . Time elapsed: 14.29 sec
# End of iteration 4 . Time elapsed: 14.72 sec
# End of iteration 5 . Time elapsed: 15.35 sec
# End of iteration 6 . Time elapsed: 16.84 sec
# End of iteration 7 . Time elapsed: 16.22 sec
# End of iteration 8 . Time elapsed: 16.61 sec
# End of iteration 9 . Time elapsed: 17.17 sec
# End of iteration 10 . Time elapsed: 17.45 sec
# End of iteration 11 . Time elapsed: 19.41 sec
# End of iteration 12 . Time elapsed: 18.71 sec
# End of iteration 13 . Time elapsed: 19.09 sec
# End of iteration 14 . Time elapsed: 19.87 sec
# End of iteration 15 . Time elapsed: 20.14 sec
# End of iteration 16 . Time elapsed: 22.14 sec
# End of iteration 17 . Time elapsed: 21.37 sec
# End of iteration 18 . Time elapsed: 21.54 sec
# End of iteration 19 . Time elapsed: 22.99 sec
# End of simulation . Time elapsed: 356.08 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of load iteration 1 ---------------------------
# End of iteration 0 . Time elapsed: 10.48 sec
# End of iteration 1 . Time elapsed: 15.85 sec
# End of iteration 2 . Time elapsed: 14.59 sec
# End of iteration 3 . Time elapsed: 14.49 sec
# End of iteration 4 . Time elapsed: 14.04 sec
# End of iteration 5 . Time elapsed: 14.23 sec
# End of iteration 6 . Time elapsed: 13.54 sec
# End of iteration 7 . Time elapsed: 13.91 sec
# End of iteration 8 . Time elapsed: 14.5 sec
# End of iteration 9 . Time elapsed: 15.34 sec
# End of iteration 10 . Time elapsed: 15.45 sec
# End of iteration 11 . Time elapsed: 15.46 sec
# End of iteration 12 . Time elapsed: 16.19 sec
# End of iteration 13 . Time elapsed: 17.1 sec
# End of iteration 14 . Time elapsed: 16.94 sec
# End of iteration 15 . Time elapsed: 17.18 sec
# End of iteration 16 . Time elapsed: 17.93 sec
# End of iteration 17 . Time elapsed: 18.23 sec
# End of iteration 18 . Time elapsed: 19.6 sec
# End of iteration 19 . Time elapsed: 19.09 sec
# End of iteration 20 . Time elapsed: 19.67 sec
# End of iteration 21 . Time elapsed: 20.06 sec
# End of iteration 22 . Time elapsed: 20.6 sec
# End of iteration 23 . Time elapsed: 21.81 sec
# End of iteration 24 . Time elapsed: 21.53 sec
# End of iteration 25 . Time elapsed: 22.02 sec
# Agents paths converged to user-equilibrium
# End of iteration 26 . Time elapsed: 22.7 sec
# End of simulation . Time elapsed: 462.96 sec
# End of iteration 0 . Time elapsed: 21.67 sec
# End of iteration 1 . Time elapsed: 22.07 sec
# End of iteration 2 . Time elapsed: 22.52 sec
# End of iteration 3 . Time elapsed: 24.4 sec
# End of iteration 4 . Time elapsed: 22.99 sec
# End of iteration 5 . Time elapsed: 23.77 sec
# End of iteration 6 . Time elapsed: 23.97 sec
# End of iteration 7 . Time elapsed: 24.36 sec
# End of iteration 8 . Time elapsed: 24.68 sec
# Agents paths converged to user-equilibrium
# End of iteration 9 . Time elapsed: 25.5 sec
# End of simulation . Time elapsed: 236.4 sec
# Preprocessing is done in 1.99 sec
# End of iteration 0 . Time elapsed: 91.19 sec
# End of iteration 1 . Time elapsed: 92.24 sec
# End of iteration 2 . Time elapsed: 93.57 sec
# End of iteration 3 . Time elapsed: 93.4 sec
# End of iteration 4 . Time elapsed: 98.66 sec
# End of iteration 5 . Time elapsed: 98.13 sec
# End of iteration 6 . Time elapsed: 100.67 sec
# End of iteration 7 . Time elapsed: 102.99 sec
# End of iteration 8 . Time elapsed: 106.16 sec
# End of iteration 9 . Time elapsed: 108.15 sec
# End of simulation . Time elapsed: 987.16 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 0 ---------------------------
# End of iteration 0 . Time elapsed: 20.67 sec
# End of iteration 1 . Time elapsed: 20.56 sec
# End of iteration 2 . Time elapsed: 21.14 sec
# End of iteration 3 . Time elapsed: 21.31 sec
# End of iteration 4 . Time elapsed: 21.1 sec
# End of iteration 5 . Time elapsed: 23.96 sec
# Agents paths converged to user-equilibrium
# End of iteration 6 . Time elapsed: 21.84 sec
# End of simulation . Time elapsed: 151.01 sec
# Preprocessing is done in 3.32 sec
# End of iteration 0 . Time elapsed: 108.85 sec
# End of iteration 1 . Time elapsed: 101.31 sec
# End of iteration 2 . Time elapsed: 139.61 sec
# End of iteration 3 . Time elapsed: 162.15 sec
# End of iteration 4 . Time elapsed: 175.77 sec
# End of iteration 5 . Time elapsed: 189.77 sec
# End of iteration 6 . Time elapsed: 196.77 sec
# End of iteration 7 . Time elapsed: 203.28 sec
# End of iteration 8 . Time elapsed: 212.01 sec
# End of iteration 9 . Time elapsed: 218.9 sec
# End of simulation . Time elapsed: 1711.74 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 1 ---------------------------
# End of iteration 0 . Time elapsed: 19.21 sec
# End of iteration 1 . Time elapsed: 19.52 sec
# End of iteration 2 . Time elapsed: 19.28 sec
# End of iteration 3 . Time elapsed: 19.58 sec
# End of iteration 4 . Time elapsed: 19.6 sec
# Agents paths converged to user-equilibrium
# End of iteration 5 . Time elapsed: 19.77 sec
# End of simulation . Time elapsed: 117.38 sec
# Preprocessing is done in 1.22 sec
# End of iteration 0 . Time elapsed: 190.05 sec
# End of iteration 1 . Time elapsed: 213.94 sec
# End of iteration 2 . Time elapsed: 247.81 sec
# End of iteration 3 . Time elapsed: 268.99 sec
# End of iteration 4 . Time elapsed: 291.27 sec
# End of iteration 5 . Time elapsed: 308.38 sec
# End of iteration 6 . Time elapsed: 329.56 sec
# End of iteration 7 . Time elapsed: 350.12 sec
# End of iteration 8 . Time elapsed: 361.98 sec
# End of iteration 9 . Time elapsed: 378.36 sec
# End of simulation . Time elapsed: 2941.68 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 2 ---------------------------
# End of simulation . Time elapsed: 18.47 sec
# Preprocessing is done in 2.12 sec
# End of simulation . Time elapsed: 267.73 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 3 ---------------------------
# Preprocessing is done in 0.3 sec
# End of iteration 0 . Time elapsed: 324.2 sec
# End of iteration 1 . Time elapsed: 310.51 sec
# End of iteration 2 . Time elapsed: 320.42 sec
# End of iteration 3 . Time elapsed: 308.68 sec
# End of iteration 4 . Time elapsed: 294.99 sec
# End of iteration 5 . Time elapsed: 298.08 sec
# End of iteration 6 . Time elapsed: 298.21 sec
# End of iteration 7 . Time elapsed: 291.16 sec
# End of iteration 8 . Time elapsed: 283.99 sec
# End of iteration 9 . Time elapsed: 287.3 sec
# End of iteration 10 . Time elapsed: 281.84 sec
# End of iteration 11 . Time elapsed: 282.32 sec
# End of iteration 12 . Time elapsed: 285.56 sec
# End of iteration 13 . Time elapsed: 284.73 sec
# End of iteration 14 . Time elapsed: 286.71 sec
# End of iteration 15 . Time elapsed: 287.65 sec
# End of iteration 16 . Time elapsed: 280.11 sec
# End of iteration 17 . Time elapsed: 279.66 sec
# End of iteration 18 . Time elapsed: 284.35 sec
# End of iteration 19 . Time elapsed: 279.82 sec
# End of simulation . Time elapsed: 5850.62 sec
# Preprocessing is done in 0.3 sec
# End of iteration 0 . Time elapsed: 28.38 sec
# End of iteration 1 . Time elapsed: 29.06 sec
# End of iteration 2 . Time elapsed: 30.0 sec
# End of iteration 3 . Time elapsed: 30.77 sec
# End of iteration 4 . Time elapsed: 33.82 sec
# End of iteration 5 . Time elapsed: 34.01 sec
# End of iteration 6 . Time elapsed: 34.5 sec
# End of iteration 7 . Time elapsed: 33.31 sec
# End of iteration 8 . Time elapsed: 34.5 sec
# End of iteration 9 . Time elapsed: 34.78 sec
# End of iteration 10 . Time elapsed: 38.03 sec
# End of iteration 11 . Time elapsed: 38.59 sec
# End of iteration 12 . Time elapsed: 40.46 sec
# End of iteration 13 . Time elapsed: 38.64 sec
# End of iteration 14 . Time elapsed: 39.17 sec
# End of iteration 15 . Time elapsed: 39.45 sec
# End of iteration 16 . Time elapsed: 40.78 sec
# End of iteration 17 . Time elapsed: 41.84 sec
# End of iteration 18 . Time elapsed: 42.66 sec
# End of iteration 19 . Time elapsed: 43.77 sec
# End of simulation . Time elapsed: 726.83 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of load iteration 2 ---------------------------
# End of iteration 0 . Time elapsed: 16.17 sec
# End of iteration 1 . Time elapsed: 39.06 sec
# End of iteration 2 . Time elapsed: 35.74 sec
# End of iteration 3 . Time elapsed: 35.6 sec
# End of iteration 4 . Time elapsed: 34.89 sec
# End of iteration 5 . Time elapsed: 24.61 sec
# End of iteration 6 . Time elapsed: 22.35 sec
# End of iteration 7 . Time elapsed: 22.5 sec
# End of iteration 8 . Time elapsed: 22.59 sec
# End of iteration 9 . Time elapsed: 22.97 sec
# End of iteration 10 . Time elapsed: 24.3 sec
# End of iteration 11 . Time elapsed: 24.38 sec
# End of iteration 12 . Time elapsed: 24.87 sec
# End of iteration 13 . Time elapsed: 26.22 sec
# End of iteration 14 . Time elapsed: 25.94 sec
# End of iteration 15 . Time elapsed: 26.75 sec
# End of iteration 16 . Time elapsed: 27.4 sec
# End of iteration 17 . Time elapsed: 28.97 sec
# End of iteration 18 . Time elapsed: 28.74 sec
# End of iteration 19 . Time elapsed: 29.55 sec
# End of iteration 20 . Time elapsed: 30.17 sec
# End of iteration 21 . Time elapsed: 30.84 sec
# End of iteration 22 . Time elapsed: 32.53 sec
# End of iteration 23 . Time elapsed: 32.31 sec
# End of iteration 24 . Time elapsed: 32.99 sec
# End of iteration 25 . Time elapsed: 33.59 sec
# End of iteration 26 . Time elapsed: 35.22 sec
# End of iteration 27 . Time elapsed: 35.09 sec
# End of iteration 28 . Time elapsed: 35.77 sec
# End of iteration 29 . Time elapsed: 36.64 sec
# End of simulation . Time elapsed: 879.38 sec
# End of iteration 0 . Time elapsed: 34.99 sec
# End of iteration 1 . Time elapsed: 37.76 sec
# End of iteration 2 . Time elapsed: 36.52 sec
# End of iteration 3 . Time elapsed: 37.34 sec
# End of iteration 4 . Time elapsed: 37.74 sec
# End of iteration 5 . Time elapsed: 38.58 sec
# End of iteration 6 . Time elapsed: 38.92 sec
# End of iteration 7 . Time elapsed: 41.62 sec
# End of iteration 8 . Time elapsed: 40.19 sec
# End of iteration 9 . Time elapsed: 41.61 sec
# End of simulation . Time elapsed: 385.3 sec
# Preprocessing is done in 3.32 sec
# End of iteration 0 . Time elapsed: 118.78 sec
# End of iteration 1 . Time elapsed: 120.33 sec
# End of iteration 2 . Time elapsed: 119.62 sec
# End of iteration 3 . Time elapsed: 119.83 sec
# End of iteration 4 . Time elapsed: 116.52 sec
# End of iteration 5 . Time elapsed: 116.85 sec
# End of iteration 6 . Time elapsed: 114.82 sec
# End of iteration 7 . Time elapsed: 117.09 sec
# End of iteration 8 . Time elapsed: 113.78 sec
# End of iteration 9 . Time elapsed: 118.66 sec
# End of simulation . Time elapsed: 1179.64 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 0 ---------------------------
# End of iteration 0 . Time elapsed: 36.58 sec
# End of iteration 1 . Time elapsed: 34.13 sec
# End of iteration 2 . Time elapsed: 34.56 sec
# End of iteration 3 . Time elapsed: 34.49 sec
# End of iteration 4 . Time elapsed: 35.26 sec
# End of iteration 5 . Time elapsed: 39.52 sec
# End of iteration 6 . Time elapsed: 35.79 sec
# End of iteration 7 . Time elapsed: 36.6 sec
# End of iteration 8 . Time elapsed: 36.66 sec
# End of iteration 9 . Time elapsed: 40.36 sec
# End of simulation . Time elapsed: 363.97 sec
# Preprocessing is done in 6.25 sec
# End of iteration 0 . Time elapsed: 196.94 sec
# End of iteration 1 . Time elapsed: 200.74 sec
# End of iteration 2 . Time elapsed: 201.25 sec
# End of iteration 3 . Time elapsed: 199.65 sec
# End of iteration 4 . Time elapsed: 206.59 sec
# End of iteration 5 . Time elapsed: 222.05 sec
# End of iteration 6 . Time elapsed: 235.13 sec
# End of iteration 7 . Time elapsed: 254.8 sec
# End of iteration 8 . Time elapsed: 268.32 sec
# End of iteration 9 . Time elapsed: 283.15 sec
# End of simulation . Time elapsed: 2274.88 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 1 ---------------------------
# End of iteration 0 . Time elapsed: 31.73 sec
# End of iteration 1 . Time elapsed: 31.97 sec
# End of iteration 2 . Time elapsed: 32.25 sec
# End of iteration 3 . Time elapsed: 32.37 sec
# End of iteration 4 . Time elapsed: 32.37 sec
# End of iteration 5 . Time elapsed: 32.38 sec
# End of iteration 6 . Time elapsed: 32.6 sec
# End of iteration 7 . Time elapsed: 32.83 sec
# End of iteration 8 . Time elapsed: 32.85 sec
# End of iteration 9 . Time elapsed: 37.31 sec
# End of simulation . Time elapsed: 328.67 sec
# Preprocessing is done in 6.48 sec
# End of iteration 0 . Time elapsed: 258.19 sec
# End of iteration 1 . Time elapsed: 295.35 sec
# End of iteration 2 . Time elapsed: 354.11 sec
# End of iteration 3 . Time elapsed: 387.07 sec
# End of iteration 4 . Time elapsed: 418.03 sec
# End of iteration 5 . Time elapsed: 454.47 sec
# End of iteration 6 . Time elapsed: 484.04 sec
# End of iteration 7 . Time elapsed: 504.61 sec
# End of iteration 8 . Time elapsed: 528.4 sec
# End of iteration 9 . Time elapsed: 548.54 sec
# End of simulation . Time elapsed: 4239.31 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 2 ---------------------------
# End of simulation . Time elapsed: 30.54 sec
# Preprocessing is done in 3.02 sec
# End of simulation . Time elapsed: 362.53 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of proportion iteration 3 ---------------------------
# Preprocessing is done in 0.54 sec
# End of iteration 0 . Time elapsed: 463.84 sec
# End of iteration 1 . Time elapsed: 456.6 sec
# End of iteration 2 . Time elapsed: 447.48 sec
# End of iteration 3 . Time elapsed: 425.19 sec
# End of iteration 4 . Time elapsed: 434.89 sec
# End of iteration 5 . Time elapsed: 407.17 sec
# End of iteration 6 . Time elapsed: 414.39 sec
# End of iteration 7 . Time elapsed: 407.93 sec
# End of iteration 8 . Time elapsed: 405.06 sec
# End of iteration 9 . Time elapsed: 400.15 sec
# End of iteration 10 . Time elapsed: 400.67 sec
# End of iteration 11 . Time elapsed: 397.48 sec
# End of iteration 12 . Time elapsed: 396.83 sec
# End of iteration 13 . Time elapsed: 391.81 sec
# End of iteration 14 . Time elapsed: 387.66 sec
# End of iteration 15 . Time elapsed: 413.61 sec
# End of iteration 16 . Time elapsed: 431.5 sec
# End of iteration 17 . Time elapsed: 424.81 sec
# End of iteration 18 . Time elapsed: 435.85 sec
# End of iteration 19 . Time elapsed: 426.32 sec
# End of simulation . Time elapsed: 8369.81 sec
# Preprocessing is done in 0.56 sec
# End of iteration 0 . Time elapsed: 52.44 sec
# End of iteration 1 . Time elapsed: 52.87 sec
# End of iteration 2 . Time elapsed: 58.16 sec
# End of iteration 3 . Time elapsed: 55.65 sec
# End of iteration 4 . Time elapsed: 55.7 sec
# End of iteration 5 . Time elapsed: 54.75 sec
# End of iteration 6 . Time elapsed: 60.63 sec
# End of iteration 7 . Time elapsed: 58.56 sec
# End of iteration 8 . Time elapsed: 60.01 sec
# End of iteration 9 . Time elapsed: 60.68 sec
# End of iteration 10 . Time elapsed: 63.19 sec
# End of iteration 11 . Time elapsed: 64.06 sec
# End of iteration 12 . Time elapsed: 64.05 sec
# End of iteration 13 . Time elapsed: 66.52 sec
# End of iteration 14 . Time elapsed: 67.85 sec
# End of iteration 15 . Time elapsed: 69.08 sec
# End of iteration 16 . Time elapsed: 77.42 sec
# End of iteration 17 . Time elapsed: 73.97 sec
# End of iteration 18 . Time elapsed: 71.63 sec
# End of iteration 19 . Time elapsed: 74.62 sec
# End of simulation . Time elapsed: 1262.42 sec
# -----------------------------------------------------------------------------------
# ------------------------------End of load iteration 3 ---------------------------
# -----------------------------------------------------------------------------------
# ------------------------------End of arch iteration---------------------------
# Time elapsed in total 46647.92852520943

# %%
data
# Out:
# {'graph': <networkx.classes.digraph.DiGraph at 0x11dce9860>,
#  'loop': [[{'TTT_DS': 824.51,
#     'TTT_DS2': 825.45,
#     'TTT_PTA': 829.38,
#     'TTT_base': 827.57,
#     'TTT_navi': 826.95,
#     'convergence_DS': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      827.4,
#      826.93,
#      826.17,
#      826.36,
#      824.98,
#      825.88,
#      825.19,
#      825.16,
#      825.1,
#      824.6,
#      824.64,
#      824.77,
#      824.84,
#      824.94,
#      824.43,
#      824.76,
#      824.99,
#      824.57,
#      824.76,
#      824.51],
#     'convergence_DS2': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      828.05,
#      826.28,
#      826.5,
#      825.78,
#      826.6,
#      826.71,
#      826.01,
#      825.89,
#      825.78,
#      825.94,
#      826.59,
#      826.02,
#      826.87,
#      825.91,
#      825.83,
#      825.61,
#      826.39,
#      825.59,
#      825.55,
#      825.45],
#     'convergence_PTA': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      826.41,
#      826.02,
#      826.6,
#      826.4,
#      827.06,
#      827.39,
#      828.13,
#      827.79,
#      828.72,
#      829.38],
#     'convergence_base': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      827.57],
#     'convergence_navi': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      826.95,
#      826.95],
#     'decomposition': [{'PTA': 142, 'base': 1334, 'navigator': 919},
#      {'PTA': 273, 'base': 1458, 'navigator': 664},
#      {'PTA': 233, 'base': 1364, 'navigator': 798},
#      {'PTA': 169, 'base': 1444, 'navigator': 782},
#      {'PTA': 183, 'base': 1183, 'navigator': 1029},
#      {'PTA': 181, 'base': 1157, 'navigator': 1057},
#      {'PTA': 115, 'base': 1599, 'navigator': 681},
#      {'PTA': 103, 'base': 1608, 'navigator': 684},
#      {'PTA': 101, 'base': 1615, 'navigator': 679},
#      {'PTA': 87, 'base': 1632, 'navigator': 676},
#      {'PTA': 103, 'base': 1568, 'navigator': 724},
#      {'PTA': 152, 'base': 1178, 'navigator': 1065},
#      {'PTA': 177, 'base': 985, 'navigator': 1233},
#      {'PTA': 84, 'base': 1620, 'navigator': 691},
#      {'PTA': 126, 'base': 1384, 'navigator': 885},
#      {'PTA': 78, 'base': 1640, 'navigator': 677},
#      {'PTA': 113, 'base': 1399, 'navigator': 883},
#      {'PTA': 81, 'base': 1645, 'navigator': 669},
#      {'PTA': 75, 'base': 1648, 'navigator': 672},
#      {'PTA': 78, 'base': 1663, 'navigator': 654}],
#     'decomposition2': [{'PTA': 0, 'base': 1536, 'navigator': 859},
#      {'PTA': 0, 'base': 1631, 'navigator': 764},
#      {'PTA': 0, 'base': 1522, 'navigator': 873},
#      {'PTA': 0, 'base': 1551, 'navigator': 844},
#      {'PTA': 0, 'base': 1312, 'navigator': 1083},
#      {'PTA': 0, 'base': 1296, 'navigator': 1099},
#      {'PTA': 0, 'base': 1668, 'navigator': 727},
#      {'PTA': 0, 'base': 1687, 'navigator': 708},
#      {'PTA': 0, 'base': 1692, 'navigator': 703},
#      {'PTA': 0, 'base': 1704, 'navigator': 691},
#      {'PTA': 0, 'base': 1659, 'navigator': 736},
#      {'PTA': 0, 'base': 1308, 'navigator': 1087},
#      {'PTA': 0, 'base': 1147, 'navigator': 1248},
#      {'PTA': 0, 'base': 1693, 'navigator': 702},
#      {'PTA': 0, 'base': 1515, 'navigator': 880},
#      {'PTA': 0, 'base': 1717, 'navigator': 678},
#      {'PTA': 0, 'base': 1494, 'navigator': 901},
#      {'PTA': 0, 'base': 1722, 'navigator': 673},
#      {'PTA': 0, 'base': 1728, 'navigator': 667},
#      {'PTA': 0, 'base': 1728, 'navigator': 667}],
#     'diff_DS': 0.0054,
#     'diff_DS2': 0.0051,
#     'diff_PTA': 0.017,
#     'diff_base': 0.0012,
#     'diff_navi': 0.0045,
#     'path_count': 2395,
#     'prop_PTA_users': 0.2625,
#     'prop_navi_users': 0.235},
#    {'TTT_PTA': 831.55,
#     'TTT_base': 827.57,
#     'TTT_navi': 826.88,
#     'convergence_PTA': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      828.15,
#      827.76,
#      827.72,
#      828.97,
#      829.11,
#      830.36,
#      829.49,
#      830.26,
#      831.54,
#      831.55],
#     'convergence_base': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      827.57],
#     'convergence_navi': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      826.88,
#      826.88],
#     'diff_PTA': 0.0563,
#     'diff_base': 0.0012,
#     'diff_navi': 0.0068,
#     'path_count': 2395,
#     'prop_PTA_users': 0.51,
#     'prop_navi_users': 0.48625},
#    {'TTT_PTA': 834.32,
#     'TTT_base': 827.57,
#     'TTT_navi': 828.76,
#     'convergence_PTA': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      825.51,
#      828.67,
#      827.67,
#      832.14,
#      831.62,
#      831.97,
#      834.81,
#      835.05,
#      833.22,
#      834.32],
#     'convergence_base': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      827.57],
#     'convergence_navi': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      828.84,
#      828.76,
#      828.76],
#     'diff_PTA': 0.1136,
#     'diff_base': 0.0012,
#     'diff_navi': 0.0101,
#     'path_count': 2395,
#     'prop_PTA_users': 0.77,
#     'prop_navi_users': 0.7325},
#    {'TTT_PTA': 824.24,
#     'TTT_base': 827.57,
#     'TTT_navi': 830.76,
#     'convergence_PTA': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      824.24],
#     'convergence_base': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      827.57],
#     'convergence_navi': [833.23,
#      844.14,
#      828.91,
#      827.78,
#      827.58,
#      827.59,
#      827.57,
#      830.76],
#     'diff_PTA': 0.0012,
#     'diff_base': 0.0012,
#     'diff_navi': 0.0128,
#     'path_count': 2395,
#     'prop_PTA_users': 1.0,
#     'prop_navi_users': 1.0}],
#   [{'TTT_DS': 1317.35,
#     'TTT_DS2': 1320.0,
#     'TTT_PTA': 1321.69,
#     'TTT_base': 1325.97,
#     'TTT_navi': 1323.65,
#     'convergence_DS': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1321.95,
#      1321.41,
#      1321.42,
#      1320.53,
#      1319.04,
#      1318.77,
#      1318.51,
#      1318.25,
#      1317.73,
#      1318.61,
#      1318.74,
#      1318.2,
#      1317.98,
#      1317.55,
#      1317.75,
#      1317.49,
#      1316.89,
#      1316.96,
#      1317.43,
#      1317.35],
#     'convergence_DS2': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1324.4,
#      1322.65,
#      1321.57,
#      1323.11,
#      1321.92,
#      1321.51,
#      1321.61,
#      1320.92,
#      1320.65,
#      1320.73,
#      1320.51,
#      1320.55,
#      1320.54,
#      1320.68,
#      1319.9,
#      1319.89,
#      1319.78,
#      1319.87,
#      1319.91,
#      1320.0],
#     'convergence_PTA': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1320.99,
#      1321.48,
#      1321.12,
#      1322.71,
#      1322.22,
#      1323.33,
#      1323.86,
#      1323.39,
#      1324.84,
#      1321.69],
#     'convergence_base': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1325.97],
#     'convergence_navi': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1323.9,
#      1323.85,
#      1323.64,
#      1323.56,
#      1323.7,
#      1323.65,
#      1323.65],
#     'decomposition': [{'PTA': 888, 'base': 1133, 'navigator': 1648},
#      {'PTA': 523, 'base': 1750, 'navigator': 1396},
#      {'PTA': 432, 'base': 1763, 'navigator': 1474},
#      {'PTA': 278, 'base': 1887, 'navigator': 1504},
#      {'PTA': 235, 'base': 2191, 'navigator': 1243},
#      {'PTA': 220, 'base': 2252, 'navigator': 1197},
#      {'PTA': 195, 'base': 2297, 'navigator': 1177},
#      {'PTA': 197, 'base': 2332, 'navigator': 1140},
#      {'PTA': 188, 'base': 2324, 'navigator': 1157},
#      {'PTA': 184, 'base': 2136, 'navigator': 1349},
#      {'PTA': 189, 'base': 2013, 'navigator': 1467},
#      {'PTA': 155, 'base': 2399, 'navigator': 1115},
#      {'PTA': 165, 'base': 2268, 'navigator': 1236},
#      {'PTA': 151, 'base': 2440, 'navigator': 1078},
#      {'PTA': 143, 'base': 2325, 'navigator': 1201},
#      {'PTA': 147, 'base': 2434, 'navigator': 1088},
#      {'PTA': 137, 'base': 2450, 'navigator': 1082},
#      {'PTA': 138, 'base': 2451, 'navigator': 1080},
#      {'PTA': 147, 'base': 2206, 'navigator': 1316},
#      {'PTA': 136, 'base': 2346, 'navigator': 1187}],
#     'decomposition2': [{'PTA': 0, 'base': 1873, 'navigator': 1796},
#      {'PTA': 0, 'base': 2086, 'navigator': 1583},
#      {'PTA': 0, 'base': 2108, 'navigator': 1561},
#      {'PTA': 0, 'base': 2137, 'navigator': 1532},
#      {'PTA': 0, 'base': 2394, 'navigator': 1275},
#      {'PTA': 0, 'base': 2436, 'navigator': 1233},
#      {'PTA': 0, 'base': 2481, 'navigator': 1188},
#      {'PTA': 0, 'base': 2495, 'navigator': 1174},
#      {'PTA': 0, 'base': 2497, 'navigator': 1172},
#      {'PTA': 0, 'base': 2309, 'navigator': 1360},
#      {'PTA': 0, 'base': 2195, 'navigator': 1474},
#      {'PTA': 0, 'base': 2547, 'navigator': 1122},
#      {'PTA': 0, 'base': 2446, 'navigator': 1223},
#      {'PTA': 0, 'base': 2577, 'navigator': 1092},
#      {'PTA': 0, 'base': 2455, 'navigator': 1214},
#      {'PTA': 0, 'base': 2601, 'navigator': 1068},
#      {'PTA': 0, 'base': 2602, 'navigator': 1067},
#      {'PTA': 0, 'base': 2614, 'navigator': 1055},
#      {'PTA': 0, 'base': 2355, 'navigator': 1314},
#      {'PTA': 0, 'base': 2529, 'navigator': 1140}],
#     'diff_DS': 0.01,
#     'diff_DS2': 0.0088,
#     'diff_PTA': 0.0198,
#     'diff_base': 0.0028,
#     'diff_navi': 0.0077,
#     'path_count': 3669,
#     'prop_PTA_users': 0.25333333333333335,
#     'prop_navi_users': 0.24166666666666667},
#    {'TTT_PTA': 1346.58,
#     'TTT_base': 1325.97,
#     'TTT_navi': 1326.38,
#     'convergence_PTA': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1321.44,
#      1321.91,
#      1327.06,
#      1329.97,
#      1341.11,
#      1339.48,
#      1345.22,
#      1341.4,
#      1348.38,
#      1346.58],
#     'convergence_base': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1325.97],
#     'convergence_navi': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1327.05,
#      1326.38,
#      1326.38],
#     'diff_PTA': 0.1161,
#     'diff_base': 0.0028,
#     'diff_navi': 0.0126,
#     'path_count': 3669,
#     'prop_PTA_users': 0.47,
#     'prop_navi_users': 0.49916666666666665},
#    {'TTT_PTA': 1331.05,
#     'TTT_base': 1325.97,
#     'TTT_navi': 1326.23,
#     'convergence_PTA': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1319.72,
#      1323.01,
#      1320.91,
#      1324.42,
#      1326.4,
#      1324.92,
#      1328.54,
#      1327.55,
#      1328.4,
#      1331.05],
#     'convergence_base': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1325.97],
#     'convergence_navi': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1326.88,
#      1326.45,
#      1326.23,
#      1326.23],
#     'diff_PTA': 0.1629,
#     'diff_base': 0.0028,
#     'diff_navi': 0.0164,
#     'path_count': 3669,
#     'prop_PTA_users': 0.7358333333333333,
#     'prop_navi_users': 0.7575},
#    {'TTT_PTA': 1319.77,
#     'TTT_base': 1325.97,
#     'TTT_navi': 1329.4,
#     'convergence_PTA': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1319.77],
#     'convergence_base': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1325.97],
#     'convergence_navi': [1338.83,
#      1443.24,
#      1355.94,
#      1339.39,
#      1330.8,
#      1326.15,
#      1326.12,
#      1326.09,
#      1325.97,
#      1329.4],
#     'diff_PTA': 0.0025,
#     'diff_base': 0.0028,
#     'diff_navi': 0.0209,
#     'path_count': 3669,
#     'prop_PTA_users': 1.0,
#     'prop_navi_users': 1.0}],
#   [{'TTT_DS': 1843.54,
#     'TTT_DS2': 1843.86,
#     'TTT_PTA': 1884.7,
#     'TTT_base': 1898.06,
#     'TTT_navi': 1880.34,
#     'convergence_DS': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1851.58,
#      1853.5,
#      1847.86,
#      1849.61,
#      1846.36,
#      1846.79,
#      1847.2,
#      1845.11,
#      1845.02,
#      1844.27,
#      1845.76,
#      1846.87,
#      1844.51,
#      1844.96,
#      1844.48,
#      1843.36,
#      1844.2,
#      1842.91,
#      1843.27,
#      1843.54],
#     'convergence_DS2': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1853.67,
#      1847.97,
#      1846.61,
#      1846.31,
#      1847.83,
#      1847.67,
#      1846.2,
#      1847.92,
#      1847.05,
#      1846.35,
#      1846.94,
#      1845.87,
#      1845.39,
#      1845.31,
#      1844.66,
#      1844.15,
#      1844.9,
#      1845.77,
#      1843.73,
#      1843.86],
#     'convergence_PTA': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1871.73,
#      1880.11,
#      1875.77,
#      1883.06,
#      1879.06,
#      1885.39,
#      1881.23,
#      1883.14,
#      1882.95,
#      1884.7],
#     'convergence_base': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1898.06],
#     'convergence_navi': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1881.94,
#      1882.65,
#      1880.94,
#      1880.53,
#      1880.69,
#      1881.08,
#      1880.75,
#      1878.98,
#      1880.34,
#      1880.34],
#     'decomposition': [{'PTA': 1633, 'base': 1225, 'navigator': 1933},
#      {'PTA': 1056, 'base': 1716, 'navigator': 2019},
#      {'PTA': 784, 'base': 2122, 'navigator': 1885},
#      {'PTA': 606, 'base': 2434, 'navigator': 1751},
#      {'PTA': 529, 'base': 2526, 'navigator': 1736},
#      {'PTA': 466, 'base': 2593, 'navigator': 1732},
#      {'PTA': 433, 'base': 2595, 'navigator': 1763},
#      {'PTA': 385, 'base': 2486, 'navigator': 1920},
#      {'PTA': 371, 'base': 2779, 'navigator': 1641},
#      {'PTA': 352, 'base': 2609, 'navigator': 1830},
#      {'PTA': 347, 'base': 2579, 'navigator': 1865},
#      {'PTA': 326, 'base': 2699, 'navigator': 1766},
#      {'PTA': 329, 'base': 2761, 'navigator': 1701},
#      {'PTA': 313, 'base': 2920, 'navigator': 1558},
#      {'PTA': 291, 'base': 2847, 'navigator': 1653},
#      {'PTA': 287, 'base': 2732, 'navigator': 1772},
#      {'PTA': 270, 'base': 2943, 'navigator': 1578},
#      {'PTA': 261, 'base': 3040, 'navigator': 1490},
#      {'PTA': 249, 'base': 3026, 'navigator': 1516},
#      {'PTA': 244, 'base': 3105, 'navigator': 1442}],
#     'decomposition2': [{'PTA': 0, 'base': 2331, 'navigator': 2460},
#      {'PTA': 0, 'base': 2248, 'navigator': 2543},
#      {'PTA': 0, 'base': 2515, 'navigator': 2276},
#      {'PTA': 0, 'base': 2664, 'navigator': 2127},
#      {'PTA': 0, 'base': 2724, 'navigator': 2067},
#      {'PTA': 0, 'base': 2745, 'navigator': 2046},
#      {'PTA': 0, 'base': 2729, 'navigator': 2062},
#      {'PTA': 0, 'base': 2684, 'navigator': 2107},
#      {'PTA': 0, 'base': 2913, 'navigator': 1878},
#      {'PTA': 0, 'base': 2691, 'navigator': 2100},
#      {'PTA': 0, 'base': 2708, 'navigator': 2083},
#      {'PTA': 0, 'base': 2797, 'navigator': 1994},
#      {'PTA': 0, 'base': 2875, 'navigator': 1916},
#      {'PTA': 0, 'base': 3097, 'navigator': 1694},
#      {'PTA': 0, 'base': 2975, 'navigator': 1816},
#      {'PTA': 0, 'base': 2903, 'navigator': 1888},
#      {'PTA': 0, 'base': 3138, 'navigator': 1653},
#      {'PTA': 0, 'base': 3205, 'navigator': 1586},
#      {'PTA': 0, 'base': 3135, 'navigator': 1656},
#      {'PTA': 0, 'base': 3218, 'navigator': 1573}],
#     'diff_DS': 0.0156,
#     'diff_DS2': 0.0142,
#     'diff_PTA': 0.0286,
#     'diff_base': 0.0024,
#     'diff_navi': 0.0137,
#     'path_count': 4791,
#     'prop_PTA_users': 0.2625,
#     'prop_navi_users': 0.2625},
#    {'TTT_PTA': 1865.05,
#     'TTT_base': 1898.06,
#     'TTT_navi': 1867.89,
#     'convergence_PTA': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1933.26,
#      1911.04,
#      1868.46,
#      1871.41,
#      1865.15,
#      1870.07,
#      1862.67,
#      1866.92,
#      1864.16,
#      1865.05],
#     'convergence_base': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1898.06],
#     'convergence_navi': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1868.47,
#      1868.14,
#      1868.92,
#      1867.88,
#      1868.18,
#      1867.89,
#      1867.89],
#     'diff_PTA': 0.0813,
#     'diff_base': 0.0024,
#     'diff_navi': 0.0183,
#     'path_count': 4791,
#     'prop_PTA_users': 0.513125,
#     'prop_navi_users': 0.496875},
#    {'TTT_PTA': 1866.79,
#     'TTT_base': 1898.06,
#     'TTT_navi': 1863.71,
#     'convergence_PTA': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1855.37,
#      1858.11,
#      1854.28,
#      1853.04,
#      1856.21,
#      1858.6,
#      1862.01,
#      1861.21,
#      1865.46,
#      1866.79],
#     'convergence_base': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1898.06],
#     'convergence_navi': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1864.09,
#      1864.14,
#      1863.88,
#      1863.86,
#      1863.71,
#      1863.71],
#     'diff_PTA': 0.1692,
#     'diff_base': 0.0024,
#     'diff_navi': 0.0231,
#     'path_count': 4791,
#     'prop_PTA_users': 0.764375,
#     'prop_navi_users': 0.748125},
#    {'TTT_PTA': 1850.42,
#     'TTT_base': 1898.06,
#     'TTT_navi': 1864.1,
#     'convergence_PTA': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1850.42],
#     'convergence_base': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1898.06],
#     'convergence_navi': [1911.77,
#      2562.22,
#      2465.83,
#      2449.7,
#      2302.16,
#      2058.19,
#      1938.36,
#      1907.13,
#      1904.05,
#      1899.72,
#      1900.54,
#      1899.54,
#      1899.66,
#      1899.29,
#      1899.11,
#      1898.37,
#      1898.03,
#      1898.25,
#      1898.3,
#      1898.25,
#      1897.73,
#      1897.95,
#      1897.93,
#      1898.1,
#      1898.27,
#      1898.06,
#      1864.1],
#     'diff_PTA': 0.0065,
#     'diff_base': 0.0024,
#     'diff_navi': 0.029,
#     'path_count': 4791,
#     'prop_PTA_users': 1.0,
#     'prop_navi_users': 1.0}],
#   [{'TTT_DS': 2719.67,
#     'TTT_DS2': 2720.99,
#     'TTT_PTA': 2798.06,
#     'TTT_base': 2809.76,
#     'TTT_navi': 2793.6,
#     'convergence_DS': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2749.59,
#      2746.54,
#      2732.48,
#      2732.92,
#      2746.32,
#      2722.05,
#      2728.39,
#      2729.43,
#      2725.76,
#      2721.8,
#      2725.11,
#      2722.74,
#      2725.63,
#      2725.45,
#      2721.8,
#      2720.34,
#      2721.66,
#      2715.93,
#      2718.72,
#      2719.67],
#     'convergence_DS2': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2738.96,
#      2735.73,
#      2740.13,
#      2730.2,
#      2731.0,
#      2727.53,
#      2721.23,
#      2729.87,
#      2732.13,
#      2730.14,
#      2724.51,
#      2722.43,
#      2727.83,
#      2724.76,
#      2725.97,
#      2723.35,
#      2727.71,
#      2719.8,
#      2721.23,
#      2720.99],
#     'convergence_PTA': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2778.58,
#      2772.95,
#      2784.33,
#      2790.46,
#      2789.61,
#      2807.16,
#      2785.93,
#      2814.48,
#      2795.09,
#      2798.06],
#     'convergence_base': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2809.76],
#     'convergence_navi': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2804.3,
#      2809.16,
#      2794.6,
#      2799.16,
#      2795.7,
#      2799.15,
#      2796.23,
#      2791.76,
#      2791.16,
#      2793.6],
#     'decomposition': [{'PTA': 2393, 'base': 1592, 'navigator': 2241},
#      {'PTA': 1641, 'base': 2245, 'navigator': 2340},
#      {'PTA': 1095, 'base': 2661, 'navigator': 2470},
#      {'PTA': 781, 'base': 2966, 'navigator': 2479},
#      {'PTA': 694, 'base': 3027, 'navigator': 2505},
#      {'PTA': 614, 'base': 3323, 'navigator': 2289},
#      {'PTA': 555, 'base': 3227, 'navigator': 2444},
#      {'PTA': 515, 'base': 3261, 'navigator': 2450},
#      {'PTA': 505, 'base': 3420, 'navigator': 2301},
#      {'PTA': 457, 'base': 3487, 'navigator': 2282},
#      {'PTA': 458, 'base': 3664, 'navigator': 2104},
#      {'PTA': 410, 'base': 3733, 'navigator': 2083},
#      {'PTA': 401, 'base': 3614, 'navigator': 2211},
#      {'PTA': 379, 'base': 3874, 'navigator': 1973},
#      {'PTA': 367, 'base': 3987, 'navigator': 1872},
#      {'PTA': 356, 'base': 3940, 'navigator': 1930},
#      {'PTA': 339, 'base': 4121, 'navigator': 1766},
#      {'PTA': 337, 'base': 4151, 'navigator': 1738},
#      {'PTA': 321, 'base': 3943, 'navigator': 1962},
#      {'PTA': 313, 'base': 4179, 'navigator': 1734}],
#     'decomposition2': [{'PTA': 0, 'base': 2923, 'navigator': 3303},
#      {'PTA': 0, 'base': 3123, 'navigator': 3103},
#      {'PTA': 0, 'base': 3305, 'navigator': 2921},
#      {'PTA': 0, 'base': 3335, 'navigator': 2891},
#      {'PTA': 0, 'base': 3344, 'navigator': 2882},
#      {'PTA': 0, 'base': 3588, 'navigator': 2638},
#      {'PTA': 0, 'base': 3456, 'navigator': 2770},
#      {'PTA': 0, 'base': 3495, 'navigator': 2731},
#      {'PTA': 0, 'base': 3674, 'navigator': 2552},
#      {'PTA': 0, 'base': 3732, 'navigator': 2494},
#      {'PTA': 0, 'base': 3945, 'navigator': 2281},
#      {'PTA': 0, 'base': 3870, 'navigator': 2356},
#      {'PTA': 0, 'base': 3812, 'navigator': 2414},
#      {'PTA': 0, 'base': 4072, 'navigator': 2154},
#      {'PTA': 0, 'base': 4245, 'navigator': 1981},
#      {'PTA': 0, 'base': 4157, 'navigator': 2069},
#      {'PTA': 0, 'base': 4280, 'navigator': 1946},
#      {'PTA': 0, 'base': 4324, 'navigator': 1902},
#      {'PTA': 0, 'base': 4050, 'navigator': 2176},
#      {'PTA': 0, 'base': 4337, 'navigator': 1889}],
#     'diff_DS': 0.0242,
#     'diff_DS2': 0.0213,
#     'diff_PTA': 0.0509,
#     'diff_base': 0.0066,
#     'diff_navi': 0.023,
#     'path_count': 6226,
#     'prop_PTA_users': 0.2425,
#     'prop_navi_users': 0.244},
#    {'TTT_PTA': 2836.35,
#     'TTT_base': 2809.76,
#     'TTT_navi': 2764.28,
#     'convergence_PTA': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2771.34,
#      2772.46,
#      2787.98,
#      2791.75,
#      2799.48,
#      2790.96,
#      2807.3,
#      2829.68,
#      2826.86,
#      2836.35],
#     'convergence_base': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2809.76],
#     'convergence_navi': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2771.5,
#      2769.92,
#      2767.15,
#      2765.12,
#      2767.98,
#      2762.93,
#      2767.28,
#      2764.43,
#      2761.15,
#      2764.28],
#     'diff_PTA': 0.1992,
#     'diff_base': 0.0066,
#     'diff_navi': 0.0276,
#     'path_count': 6226,
#     'prop_PTA_users': 0.486,
#     'prop_navi_users': 0.4955},
#    {'TTT_PTA': 2766.12,
#     'TTT_base': 2809.76,
#     'TTT_navi': 2766.0,
#     'convergence_PTA': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2741.09,
#      2737.81,
#      2741.39,
#      2746.8,
#      2750.39,
#      2748.44,
#      2756.65,
#      2769.4,
#      2751.54,
#      2766.12],
#     'convergence_base': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2809.76],
#     'convergence_navi': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2761.5,
#      2759.31,
#      2760.58,
#      2756.17,
#      2762.3,
#      2758.07,
#      2760.48,
#      2760.81,
#      2753.17,
#      2766.0],
#     'diff_PTA': 0.2079,
#     'diff_base': 0.0066,
#     'diff_navi': 0.0324,
#     'path_count': 6226,
#     'prop_PTA_users': 0.7555,
#     'prop_navi_users': 0.7355},
#    {'TTT_PTA': 2737.25,
#     'TTT_base': 2809.76,
#     'TTT_navi': 2762.86,
#     'convergence_PTA': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2737.25],
#     'convergence_base': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2809.76],
#     'convergence_navi': [2918.73,
#      4566.6,
#      5014.37,
#      4960.74,
#      4850.47,
#      3629.13,
#      3069.35,
#      2912.64,
#      2869.08,
#      2853.61,
#      2834.27,
#      2835.75,
#      2825.39,
#      2819.72,
#      2818.34,
#      2814.1,
#      2812.19,
#      2810.59,
#      2810.1,
#      2814.14,
#      2812.1,
#      2811.55,
#      2809.25,
#      2812.79,
#      2809.54,
#      2809.19,
#      2811.24,
#      2809.1,
#      2805.47,
#      2762.86],
#     'diff_PTA': 0.014,
#     'diff_base': 0.0066,
#     'diff_navi': 0.0398,
#     'path_count': 6226,
#     'prop_PTA_users': 1.0,
#     'prop_navi_users': 1.0}]]}

# %%
#Start of figure-drawing

# %%
#Draw a graph on which the results were generated
fig = plt.figure(1)
#pos = nx.spectral_layout(data['graph'])
pos = nx.circular_layout(data['graph'])
nx.draw_networkx(data['graph'], pos = pos, node_size = 200, font_size = 10)
labels = nx.get_edge_attributes(data['graph'], 'weight')
nx.draw_networkx_edge_labels(data['graph'], pos = pos, edge_labels = labels, font_size = 10)
plt.axis('off')
plt.suptitle('Fig. 8: Randomly generated graph with 5 nodes, 10 edges \n and weights ranging from 10 to 30', 
             x = 0.5, y = 0.12, fontsize = 14, fontweight = 'normal')

plt.savefig('fig8.png', bbox_inches='tight')
plt.show()

# %%
#Gather tha data for figure-drawing
proportion_of_PTA_users = []
proportion_of_navi_users = []
TTT_base = [[] for u in range(4)]
TTT_navi = [[] for u in range(4)]
TTT_PTA = [[] for u in range(4)]
for i in range(4):
    for k in range(len(data['loop'][i])):
        proportion_of_PTA_users.append(data['loop'][i][k]['prop_PTA_users'])
        proportion_of_navi_users.append(data['loop'][i][k]['prop_navi_users'])
        TTT_base[i].append(data['loop'][i][k]['TTT_base'])
        TTT_navi[i].append(data['loop'][i][k]['TTT_navi'])
        TTT_PTA[i].append(data['loop'][i][k]['TTT_PTA'])
#display(proportion_of_PTA_users)
#display(TTT_PTA)
#display(proportion_of_navi_users)
#display(TTT_navi)
#display(TTT_base)
# Out:
# [[826.95, 826.88, 828.76, 830.76],
#  [1323.65, 1326.38, 1326.23, 1329.4],
#  [1880.34, 1867.89, 1863.71, 1864.1],
#  [2793.6, 2764.28, 2766.0, 2762.86]]
# [[827.57, 827.57, 827.57, 827.57],
#  [1325.97, 1325.97, 1325.97, 1325.97],
#  [1898.06, 1898.06, 1898.06, 1898.06],
#  [2809.76, 2809.76, 2809.76, 2809.76]]

# %%
#Create figure with comaprison of travel times obtained by the methods studied
xlabels = np.array([0.25, 0.5, 0.75, 1.0])
fig = plt.figure(figsize = (10,7))

ax0 = plt.subplot(221)
ax0.set_title('800 agents')
plt.bar(left = xlabels - 0.03, height = TTT_base[0], width = 0.03, align='center')
plt.bar(left = xlabels, height = TTT_navi[0], width = 0.03, color = 'g', align='center')
plt.bar(left = xlabels + 0.03, height = TTT_PTA[0], width = 0.03, color = 'r', align='center')
plt.xticks(xlabels)
ax0.set_ylim(ymin = 750, ymax = 850)
plt.yticks([750, 775, 800, 825, 850])

ax1 = plt.subplot(222)
ax1.set_title('1200 agents')
plt.bar(left = xlabels - 0.03, height = TTT_base[1], width = 0.03, align='center')
plt.bar(left = xlabels, height = TTT_navi[1], width = 0.03, color = 'g', align='center')
plt.bar(left = xlabels + 0.03, height = TTT_PTA[1], width = 0.03, color = 'r', align='center')
plt.xticks(xlabels)
ax1.set_ylim(ymin = 1200, ymax = 1400)
#plt.yticks([500, 600, 800, 900])

ax2 = plt.subplot(223)
ax2.set_title('1600 agents')
plt.bar(left = xlabels - 0.03, height = TTT_base[2], width = 0.03, align='center')
plt.bar(left = xlabels, height = TTT_navi[2], width = 0.03, color = 'g', align='center')
plt.bar(left = xlabels + 0.03, height = TTT_PTA[2], width = 0.03, color = 'r', align='center')
plt.xticks(xlabels)
ax2.set_ylim(ymin = 1600, ymax = 2000)
plt.yticks([1600, 1700, 1800, 1900, 2000])

ax3 = plt.subplot(224)
ax3.set_title('2000 agents')
plt.bar(left = xlabels - 0.03, height = TTT_base[3], width = 0.03, align='center')
plt.bar(left = xlabels, height = TTT_navi[3], width = 0.03, color = 'g', align='center')
plt.bar(left = xlabels + 0.03, height = TTT_PTA[3], width = 0.03, color = 'r', align='center')
plt.xticks(xlabels)
ax3.set_ylim(ymin = 2500, ymax = 2900)
plt.yticks([2500, 2600, 2700, 2800, 2900])

plt.suptitle('Fig. 11: The performance of baseline, navigator and PTA solutions \n' \
             + 'with different number of agents in the network \n' + 
             "\n(hor. axes - proportion of method's users, vert. axes - total travel time of the system)", 
             x = 0.5, y = 0.05, fontsize = 14, fontweight = 'normal')

blue_patch = mpatches.Patch(color='blue', label='Baseline')
green_patch = mpatches.Patch(color='green', label='Navigator')
red_patch = mpatches.Patch(color='red', label='PTA')

plt.legend(handles=[blue_patch, green_patch, red_patch], 
           bbox_to_anchor=(1.1, 1.3), loc=2, borderaxespad=0.0)

plt.savefig('2fig10.png', bbox_inches='tight')
plt.show()

# %%
#Gather the convergence metrics
convergence_base = []
for i in range(4):
    convergence_base.append(data['loop'][i][0]['convergence_base'])
#convergence_base
len(convergence_base[2])
# Out:
# 27

# %%
#Create figure with convergence metrics of dynamic simulation
fig = plt.figure(figsize = (10,7))

ax0 = plt.subplot(221)
ax0.set_title('800 agents')
plt.plot(convergence_base[0])
plt.xticks(list(range(0, len(convergence_base[0]), 1)))
#ax0.set_ylim(ymin = 410, ymax = 430)
#plt.yticks(list(range(410, 440, 5)))


ax1 = plt.subplot(222)
ax1.set_title('1200 agents')
plt.plot(convergence_base[1])
plt.xticks(list(range(0, len(convergence_base[1]), 1)))
ax1.set_ylim(ymin = 1320, ymax = 1450)
plt.yticks(list(range(1320, 1451, 30)))

ax2 = plt.subplot(223)
ax2.set_title('1600 agents')
plt.plot(convergence_base[2])
ax2.set_xlim(xmin = 0, xmax = 26)
plt.xticks(list(range(0, len(convergence_base[2]), 3)))
#ax2.set_ylim(ymin = 1200, ymax = 2000)
plt.yticks(list(range(1800, 2601, 200)))

ax3 = plt.subplot(224)
ax3.set_title('2000 agents')
plt.plot(convergence_base[3])
ax3.set_xlim(xmin = 0, xmax = 29)
plt.xticks(list(range(0, len(convergence_base[3]), 3)))
#ax3.set_ylim(ymin = 2200, ymax = 4000)
plt.yticks(list(range(2500, 5501, 750)))

plt.suptitle('Fig. 9: The convergence of baseline simulation to SUE with limit on # iterations equal to 30' 
             + "\n\n(hor. axes - number of iterations, vert. axes - total travel time of the system)", 
             x = 0.5, y = 0.05, fontsize = 14, fontweight = 'normal')

#plt.savefig('2fig9.png', bbox_inches='tight')
plt.show()

# %%
#Gather the convergence metrics
convergence_PTA = []
for i in range(4):
    convergence_PTA.append(data['loop'][i][0]['convergence_PTA'][len(convergence_base[i]):])
#convergence_base
len(convergence_PTA[3])
# Out:
# 9

# %%
#Create figure with convergence metrics of dynamic simulation
fig = plt.figure(figsize = (10,7))

ax0 = plt.subplot(221)
ax0.set_title('800 agents')
plt.plot(convergence_PTA[0], color = 'r')
ax0.set_ylim(ymin = 820, ymax = 840)
#plt.yticks(list(range(410, 440, 5)))


ax1 = plt.subplot(222)
ax1.set_title('1200 agents')
plt.plot(convergence_PTA[1], color = 'r')
ax1.set_ylim(ymin = 1310, ymax = 1340)
#plt.yticks(list(range(1320, 1451, 30)))
y_formatter = matplotlib.ticker.ScalarFormatter(useOffset=False)
ax1.yaxis.set_major_formatter(y_formatter)

ax2 = plt.subplot(223)
ax2.set_title('1600 agents')
plt.plot(convergence_PTA[2], color = 'r')
ax2.set_ylim(ymin = 1860, ymax = 1900)
#plt.yticks(list(range(1800, 2601, 200)))

ax3 = plt.subplot(224)
ax3.set_title('2000 agents')
plt.plot(convergence_PTA[3], color = 'r')
ax3.set_ylim(ymin = 2700, ymax = 2900)
#plt.yticks(list(range(2500, 5501, 750)))

plt.suptitle('Fig. 10: The convergence of PTA simulation to SUE with limit on # iterations equal to 10' 
             + "\n\n(hor. axes - number of iterations, vert. axes - total travel time of the system)", 
             x = 0.5, y = 0.05, fontsize = 14, fontweight = 'normal')

#plt.savefig('2fig14.png', bbox_inches='tight')
plt.show()

# %%
#Gather the convergence metrics
convergence_DS = []
convergence_DS2 = []
for i in range(4):
    convergence_DS.append(data['loop'][i][0]['convergence_DS'])
    convergence_DS2.append(data['loop'][i][0]['convergence_DS2'])
#convergence_DS2

# %%
#Create figure with convergence metrics of dynamic system
fig = plt.figure(figsize = (10,7))

ax0 = plt.subplot(221)
ax0.set_title('800 agents')
plt.plot(convergence_DS[0][len(convergence_base[0]):])
plt.plot(convergence_DS2[0][len(convergence_base[0]):])
plt.xticks(list(range(0, len(convergence_DS[0][len(convergence_base[0]):]), 3)))
#ax0.set_ylim(ymin = 415, ymax = 425)
#plt.yticks(list(range(415, 426, 2)))


ax1 = plt.subplot(222)
ax1.set_title('1200 agents')
plt.plot(convergence_DS[1][len(convergence_base[1]):])
plt.plot(convergence_DS2[1][len(convergence_base[1]):])
plt.xticks(list(range(0, len(convergence_DS[1][len(convergence_base[1]):]), 3)))
#ax1.set_ylim(ymin = 800, ymax = 820)
#plt.yticks(list(range(1315, 1326, 2)))
y_formatter = matplotlib.ticker.ScalarFormatter(useOffset=False)
ax1.yaxis.set_major_formatter(y_formatter)

ax2 = plt.subplot(223)
ax2.set_title('1600 agents')
plt.plot(convergence_DS[2][len(convergence_base[2]):])
plt.plot(convergence_DS2[2][len(convergence_base[2]):])
plt.xticks(list(range(0, len(convergence_DS[2][len(convergence_base[2]):]), 3)))
#ax2.set_ylim(ymin = 1350, ymax = 1380)
#plt.yticks(list(range(1842, 1855, 3)))

ax3 = plt.subplot(224)
ax3.set_title('2000 agents')
plt.plot(convergence_DS[3][len(convergence_base[3]):])
plt.plot(convergence_DS2[3][len(convergence_base[3]):])
plt.xticks(list(range(0, len(convergence_DS[3][len(convergence_base[3]):]), 3)))
#ax3.set_ylim(ymin = 2100, ymax = 2200)
#plt.yticks(list(range(2100, 2201, 20)))

plt.suptitle('Fig. 12: The convergence of dynamic simulation to SUE across 20 iterations' 
             + "\n\n(hor. axes - number of iterations, vert. axes - total travel time of the system)", 
             x = 0.5, y = 0.05, fontsize = 14, fontweight = 'normal')

blue_patch = mpatches.Patch(color='blue', label='dynamic system\nwith PTA')
green_patch = mpatches.Patch(color='green', label='dynamic system\nwithout PTA')

plt.legend(handles=[blue_patch, green_patch], 
           bbox_to_anchor=(1.1, 1.3), loc=2, borderaxespad=0.0)

#plt.savefig('2fig11.png', bbox_inches='tight')
plt.show()

# %%
TTT_DS = []
TTT_DS2 = []
TTT_base_prox = []
for i in range(len(data['loop'])):
    TTT_DS.append(data['loop'][i][0]['TTT_DS']/data['loop'][i][0]['path_count'])
    TTT_DS2.append(data['loop'][i][0]['TTT_DS2']/data['loop'][i][0]['path_count'])
    TTT_base_prox.append(data['loop'][i][0]['TTT_base']/data['loop'][i][0]['path_count'])
    
#display(TTT_DS)
#display(TTT_DS2)
#display(TTT_base_prox)
a = TTT_DS2[3]/TTT_base_prox[3]
b = TTT_DS[3]/TTT_base_prox[3]
c = TTT_DS[3]/TTT_DS2[3]
#a - b
c
# Out:
# 0.9995148824508727

# %%
#Create figure with comaprison of travel times obtained by the methods studied
xlabels = np.array([800, 1200, 1600, 2000])
fig = plt.figure(figsize = (10,7))

ax0 = plt.subplot(221)
plt.bar(left = xlabels - 80, height = TTT_base_prox, width = 80, align='center')
plt.bar(left = xlabels, height = TTT_DS2, width = 80, color = 'g', align='center')
plt.bar(left = xlabels + 80, height = TTT_DS, width = 80, color = 'r', align='center')
ax0.set_xlabel('Number of agents')
ax0.set_ylabel('Average travel time')
plt.xticks(xlabels)
ax0.set_ylim(ymin = 0.3, ymax = 0.46)
#plt.yticks([750, 775, 800, 825, 850])

blue_patch = mpatches.Patch(color='blue', label='Only exp.')
green_patch = mpatches.Patch(color='green', label='Exp. + navigator')
red_patch = mpatches.Patch(color='red', label='Exp + navigator + PTA')

plt.suptitle("Fig. 13: The comparion of dynamic system's average travel times",
             x = 0.4, y = 0.45, fontsize = 12, fontweight = 'normal')

plt.legend(handles=[blue_patch, green_patch, red_patch], 
           bbox_to_anchor=(1.1, 0.65), loc=2, borderaxespad=0.0, fontsize = 10)
#plt.savefig('2fig15.png', bbox_inches='tight')
plt.show()

# %%
#Decomposition of number of users by method in DS
num_PTA_users = [[] for u in range(4)]
num_navi_users = [[] for u in range(4)]
num_base_users = [[] for u in range(4)]
for i in range(len(data['loop'][i])):
    for dictionary in data['loop'][i][0]['decomposition']:
        num_PTA_users[i].append(dictionary['PTA'])
        num_navi_users[i].append(dictionary['navigator'])
        num_base_users[i].append(dictionary['base'])
num_navi_users[2][1] + num_base_users[2][1] + num_PTA_users[2][1]
# Out:
# 4791

# %%
#Create figure with convergence metrics of dynamic system
fig = plt.figure(figsize = (10,7))

ax0 = plt.subplot(221)
ax0.set_title('800 agents')
y = np.row_stack((num_PTA_users[0], num_base_users[0], num_navi_users[0]))
x = np.array(list(range(len(num_PTA_users[0]))))
plt.stackplot(x, y, colors = ('r', 'b', 'g'))
plt.xticks(list(range(0, len(num_PTA_users[0]), 3)))
plt.yticks(list(range(0, 2395, 350)))
ax0.set_ylim(ymin = 0, ymax = num_PTA_users[0][0] + num_base_users[0][0] + num_navi_users[0][0])
ax0.set_xlim(xmin = 0, xmax = len(num_base_users[0])-1)


ax1 = plt.subplot(222)
ax1.set_title('1200 agents')
y = np.row_stack((num_PTA_users[1], num_base_users[1], num_navi_users[1]))
plt.stackplot(x, y, colors = ('r', 'b', 'g'))
plt.xticks(list(range(0, len(num_PTA_users[0]), 3)))
ax1.set_ylim(ymin = 0, ymax = num_PTA_users[1][0] + num_base_users[1][0] + num_navi_users[1][0])
#plt.yticks(list(range(0, 2447, 400)))
ax1.set_xlim(xmin = 0, xmax = len(num_base_users[0])-1)

ax2 = plt.subplot(223)
ax2.set_title('1600 agents')
y = np.row_stack((num_PTA_users[2], num_base_users[2], num_navi_users[2]))
plt.stackplot(x, y, colors = ('r', 'b', 'g'))
plt.xticks(list(range(0, len(num_PTA_users[0]), 3)))
ax2.set_ylim(ymin = 0, ymax = num_PTA_users[2][0] + num_base_users[2][0] + num_navi_users[2][0])
plt.yticks(list(range(0, 4791, 600)))
ax2.set_xlim(xmin = 0, xmax = len(num_base_users[0])-1)

ax3 = plt.subplot(224)
ax3.set_title('2000 agents')
y = np.row_stack((num_PTA_users[3], num_base_users[3], num_navi_users[3]))
plt.stackplot(x, y, colors = ('r', 'b', 'g'))
plt.xticks(list(range(0, len(num_PTA_users[0]), 3)))
ax3.set_ylim(ymin = 0, ymax = num_PTA_users[3][0] + num_base_users[3][0] + num_navi_users[3][0])
#plt.yticks(list(range(0, 5022, 800)))
ax3.set_xlim(xmin = 0, xmax = len(num_base_users[0])-1)

plt.suptitle('Fig. 14: The composition of paths based on usage of routing methods with PTA as an option' 
             + "\n\n(hor. axes - number of iterations, vert. axes - total travel time of the system)", 
             x = 0.5, y = 0.05, fontsize = 14, fontweight = 'normal')

blue_patch = mpatches.Patch(color='blue', label='Baseline')
green_patch = mpatches.Patch(color='green', label='Navigator')
red_patch = mpatches.Patch(color='red', label='PTA')

plt.legend(handles=[blue_patch, green_patch, red_patch], 
           bbox_to_anchor=(1.1, 1.3), loc=2, borderaxespad=0.0)

plt.savefig('2fig12.png', bbox_inches='tight')
plt.show()

# %%
#Decomposition of number of users by method in DS
num_PTA_users2 = [[] for u in range(4)]
num_navi_users2 = [[] for u in range(4)]
num_base_users2 = [[] for u in range(4)]
for i in range(len(data['loop'][i])):
    for dictionary in data['loop'][i][0]['decomposition2']:
        num_PTA_users2[i].append(dictionary['PTA'])
        num_navi_users2[i].append(dictionary['navigator'])
        num_base_users2[i].append(dictionary['base'])
num_navi_users[2][1] + num_base_users[2][1] + num_PTA_users[2][1]
# Out:
# 4791

# %%
#Create figure with convergence metrics of dynamic system
fig = plt.figure(figsize = (10,7))

ax0 = plt.subplot(221)
ax0.set_title('800 agents')
y = np.row_stack((num_PTA_users2[0], num_base_users2[0], num_navi_users2[0]))
x = np.array(list(range(len(num_PTA_users2[0]))))
plt.stackplot(x, y, colors = ('r', 'b', 'g'))
plt.xticks(list(range(0, len(num_PTA_users2[0]), 3)))
plt.yticks(list(range(0, 2395, 350)))
ax0.set_ylim(ymin = 0, ymax = num_PTA_users2[0][0] + num_base_users2[0][0] + num_navi_users2[0][0])
ax0.set_xlim(xmin = 0, xmax = len(num_base_users2[0])-1)


ax1 = plt.subplot(222)
ax1.set_title('1200 agents')
y = np.row_stack((num_PTA_users2[1], num_base_users2[1], num_navi_users2[1]))
plt.stackplot(x, y, colors = ('r', 'b', 'g'))
plt.xticks(list(range(0, len(num_PTA_users2[0]), 3)))
ax1.set_ylim(ymin = 0, ymax = num_PTA_users2[1][0] + num_base_users2[1][0] + num_navi_users2[1][0])
#plt.yticks(list(range(0, 2447, 400)))
ax1.set_xlim(xmin = 0, xmax = len(num_base_users2[0])-1)

ax2 = plt.subplot(223)
ax2.set_title('1600 agents')
y = np.row_stack((num_PTA_users2[2], num_base_users2[2], num_navi_users2[2]))
plt.stackplot(x, y, colors = ('r', 'b', 'g'))
plt.xticks(list(range(0, len(num_PTA_users2[0]), 3)))
ax2.set_ylim(ymin = 0, ymax = num_PTA_users2[2][0] + num_base_users2[2][0] + num_navi_users2[2][0])
plt.yticks(list(range(0, 4791, 600)))
ax2.set_xlim(xmin = 0, xmax = len(num_base_users2[0])-1)

ax3 = plt.subplot(224)
ax3.set_title('2000 agents')
y = np.row_stack((num_PTA_users2[3], num_base_users2[3], num_navi_users2[3]))
plt.stackplot(x, y, colors = ('r', 'b', 'g'))
plt.xticks(list(range(0, len(num_PTA_users2[0]), 3)))
ax3.set_ylim(ymin = 0, ymax = num_PTA_users2[3][0] + num_base_users2[3][0] + num_navi_users2[3][0])
#plt.yticks(list(range(0, 5022, 800)))
ax3.set_xlim(xmin = 0, xmax = len(num_base_users2[0])-1)

plt.suptitle('Fig. 15: The composition of paths based on usage of routing methods without PTA as an option' 
             + "\n\n(hor. axes - number of iterations, vert. axes - total travel time of the system)", 
             x = 0.5, y = 0.05, fontsize = 14, fontweight = 'normal')

blue_patch = mpatches.Patch(color='blue', label='Baseline')
green_patch = mpatches.Patch(color='green', label='Navigator')

plt.legend(handles=[blue_patch, green_patch], 
           bbox_to_anchor=(1.1, 1.3), loc=2, borderaxespad=0.0)

plt.savefig('2fig13.png', bbox_inches='tight')
plt.show()

# %%
#End of figure-drawing

# %%
#Dynamic system

# %%
dynamic_simulation = dynamic_system(graph = G, agents = agents, max_time = simulation2.max_time,
                                    historical_data = simulation2.statistics[0],
                                    common_sense = deepcopy(simulation.common_sense),
                                    cars_ahead = simulation2.cars_ahead, all_three = True)

# %%
dynamic_simulation.restore_all_agents_finally()
dynamic_simulation.simulation_optimized(max_iters = 1)

# %%
def user_decomposition(dynamic_simulation):    
    decomposition = \
    [dict() for a in range(dynamic_simulation.num_baseline_iters, len(dynamic_simulation.common_sense))]
    for iteration in range(dynamic_simulation.num_baseline_iters, len(dynamic_simulation.common_sense)):
        base = 0
        PTA = 0
        navi = 0
        for a in dynamic_simulation.common_sense[iteration]:
            for p in range(len(a.paths)):
                if a.path_type[p] == 'baseline':
                    base += 1
                elif a.path_type[p] == 'navigator':
                    navi += 1
                elif a.path_type[p] == 'PTA':
                    PTA += 1
        decomposition[iteration - dynamic_simulation.num_baseline_iters]['base'] = base
        decomposition[iteration - dynamic_simulation.num_baseline_iters]['navigator'] = navi
        decomposition[iteration - dynamic_simulation.num_baseline_iters]['PTA'] = PTA
    return decomposition
        #print('Base', base)
        #print('Navi', navi)
        #print('PTA', PTA)
        #print('-------------Iteration', iteration, 'ended-----------------')

# %%
dec = user_decomposition(dynamic_simulation)
dec

# %%
compare_results(dynamic_simulation, simulation2, simulation3)
